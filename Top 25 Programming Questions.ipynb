# %% [markdown]
# # Basic Implementation
# # 1. Merge Strings Alternately
#
# Question 1: You are given two strings word1 and word2. Merge the strings by adding letters in alternating order, starting with word1.
# If a string is longer than the other, append the additional letters onto the end of the merged string. Return the merged string.

# %%
class Solution(object):
    def mergeAlternately(self, word1, word2):
        m = len(word1)
        n = len(word2)
        i = 0
        j = 0
        result = []

        while i < m or j < n:
            if i < m:
                result += word1[i]
                i += 1
            if j < n:
                result += word2[j]
                j += 1

        return "".join(result)

if __name__ == "__main__":
    word1 = input("Enter the first word: ")
    word2 = input("Enter the second word: ")

    solution = Solution()

    merged_word = solution.mergeAlternately(word1, word2)
    print("Merged Word:", merged_word)
# Out:
# Enter the first word:  abc
# Enter the second word:  pqr
# Merged Word: apbqcr

# %% [markdown]
# # 2. Find the Difference
# Question 2: You are given two strings s and t. String t is generated by random shuffling string s and then add one more letter at a random position.
# Return the letter that was added to t.

# %%
class Solution:
    def findTheDifference(self, s, t):
        # Use XOR to find the differing character
        result = 0
        for char in s + t:
            result ^= ord(char)
        return chr(result)

# Interactive Part
if __name__ == "__main__":
    # Input strings
    s = input("Enter string s: ")
    t = input("Enter string t: ")

    # Create a Solution object
    solution = Solution()

    # Find and print the added letter
    added_letter = solution.findTheDifference(s, t)
    print("The added letter is:", added_letter)
# Out:
# Enter string s:  pet
# Enter string t:  peth
# The added letter is: h

# %% [markdown]
# # 3. Find the Index of the First Occurrence in a String
# Question 3: Given two strings needle and haystack, return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.

# %%
class Solution:
    def strStr(self, haystack, needle):
        # Check if needle is empty
        if not needle:
            return 0
        
        # Loop through haystack to find the needle
        for i in range(len(haystack) - len(needle) + 1):
            # Check if substring matches needle
            if haystack[i:i+len(needle)] == needle:
                return i
        
        # If not found, return -1
        return -1

# Interactive Part
if __name__ == "__main__":
    # Input strings
    haystack = input("Enter the haystack: ")
    needle = input("Enter the needle: ")

    # Create a Solution object
    solution = Solution()

    # Find and print the result
    result = solution.strStr(haystack, needle)
    print("The index of the first occurrence is:", result)
# Out:
# Enter the haystack:  haystack
# Enter the needle:  needle
# The index of the first occurrence is: -1

# %% [markdown]
# # 4. Valid Anagram
# Given two strings s and t, return true if t is an anagram of s, and false otherwise.

# %%
def isAnagram(s, t):
    if len(s) != len(t):
        return False
    return sorted(s) == sorted(t)

# Example usage
if __name__ == "__main__":
    # Example inputs
    s1, t1 = "anagram", "nagaram"
    s2, t2 = "rat", "car"
    
    # Outputs
    print("Example 1 Output:", isAnagram(s1, t1))  # Output: True
    print("Example 2 Output:", isAnagram(s2, t2))  # Output: False
# Out:
# Example 1 Output: True
# Example 2 Output: False

# %% [markdown]
# # 5. Repeated Substring Pattern
# Given a string s, check if it can be constructed by taking a substring of it and appending multiple copies of the substring together.

# %%
def repeatedSubstringPattern(s):
    doubled = s + s  # Create a doubled version of the string
    return s in doubled[1:-1]  # Check if the original string exists within the doubled string, excluding the first and last character

# Example usage
if __name__ == "__main__":
    # Input from the user
    s = input("Enter the string: ")

    # Check and print the result
    if repeatedSubstringPattern(s):
        print("Output: True (The string can be constructed by repeating a substring)")
    else:
        print("Output: False (The string cannot be constructed by repeating a substring)")
# Out:
# Enter the string:  abcabcabc
# Output: True (The string can be constructed by repeating a substring)

# %% [markdown]
# # 6. Move Zeroes
# Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.
# Note that you must do this in-place without making a copy of the array.

# %%
def moveZeroes(nums):
    non_zero_index = 0  # Pointer for the next non-zero element
    
    # Move all non-zero elements to the front
    for i in range(len(nums)):
        if nums[i] != 0:
            nums[non_zero_index], nums[i] = nums[i], nums[non_zero_index]
            non_zero_index += 1

# Example usage
if __name__ == "__main__":
    # Input from the user
    nums = list(map(int, input("Enter the array elements separated by space: ").split()))

    # Perform the operation
    moveZeroes(nums)
    
    # Output the result
    print("Output:", nums)
# Out:
# Enter the array elements separated by space:  1 4 0 9 0 6 9 3 0 0 1
# Output: [1, 4, 9, 6, 9, 3, 1, 0, 0, 0, 0]

# %% [markdown]
# # 7. Plus One
# You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer does not contain any leading 0's.
# Increment the large integer by one and return the resulting array of digits.

# %%
def plusOne(digits):
    n = len(digits)
    
    # Traverse the digits from right to left
    for i in range(n - 1, -1, -1):
        if digits[i] < 9:
            digits[i] += 1  # Increment the digit
            return digits  # Return as no carry-over is needed
        digits[i] = 0  # Set current digit to 0 (carry-over)
    
    # If all digits are 9, add a leading 1
    return [1] + digits

# Example usage
if __name__ == "__main__":
    # Input from the user
    digits = list(map(int, input("Enter the digits separated by space: ").split()))

    # Get the incremented result
    result = plusOne(digits)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the digits separated by space:  4 5 7 8 0
# Output: [4, 5, 7, 8, 1]

# %% [markdown]
# # 8. Sign of the Product of an Array
# Implement a function signFunc(x) that returns:
#
# 1 if x is positive.
# -1 if x is negative.
# 0 if x is equal to 0.
# You are given an integer array nums. Let product be the product of all values in the array nums.
#
# Return signFunc(product).

# %%
def signFunc(x):
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

def arraySign(nums):
    product = 1
    for num in nums:
        product *= num  # Multiply each number in the array
    
    return signFunc(product)  # Return the sign of the product

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    nums = list(map(int, input("Enter the array elements separated by space: ").split()))
    
    # Get the result
    result = arraySign(nums)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the array elements separated by space:  1 3 4 0 9 4
# Output: 0

# %% [markdown]
# # 9. Can Make Arithmetic Progression From Sequence
# A sequence of numbers is called an arithmetic progression if the difference between any two consecutive elements is the same.
# Given an array of numbers arr, return true if the array can be rearranged to form an arithmetic progression. Otherwise, return false.

# %%
def canBeArithmeticProgression(arr):
    arr.sort()  # Sort the array first
    diff = arr[1] - arr[0]  # Calculate the difference between the first two elements
    
    # Check the difference for every consecutive pair in the sorted array
    for i in range(1, len(arr) - 1):
        if arr[i + 1] - arr[i] != diff:
            return False  # If the difference is not consistent, return False
    
    return True  # If the differences are consistent, return True

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    arr = list(map(int, input("Enter the array elements separated by space: ").split()))
    
    # Get the result
    result = canBeArithmeticProgression(arr)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the array elements separated by space:  1 4 8 12
# Output: False

# %% [markdown]
# # 10. Monotonic Array
# An array is monotonic if it is either monotone increasing or monotone decreasing.
# An array nums is monotone increasing if for all i <= j, nums[i] <= nums[j]. An array nums is monotone decreasing if for all i <= j, nums[i] >= nums[j].
# Given an integer array nums, return true if the given array is monotonic, or false otherwise.

# %%
def isMonotonic(nums):
    # Check if the array is monotonic increasing or decreasing
    increasing = decreasing = True
    
    for i in range(1, len(nums)):
        if nums[i] > nums[i - 1]:
            decreasing = False
        elif nums[i] < nums[i - 1]:
            increasing = False
    
    return increasing or decreasing

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    nums = list(map(int, input("Enter the array elements separated by space: ").split()))
    
    # Get the result
    result = isMonotonic(nums)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the array elements separated by space:  1 2 2 3
# Output: True

# %% [markdown]
# # 11. Roman to Integer
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# I can be placed before V (5) and X (10) to make 4 and 9.
# X can be placed before L (50) and C (100) to make 40 and 90.
# C can be placed before D (500) and M (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.

# %%
def romanToInt(s):
    # Dictionary mapping Roman symbols to their integer values
    roman_map = {
        'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000
    }
    
    result = 0
    for i in range(len(s) - 1):
        # If current Roman value is less than the next one, subtract it
        if roman_map[s[i]] < roman_map[s[i + 1]]:
            result -= roman_map[s[i]]
        else:
            result += roman_map[s[i]]
    
    # Add the value of the last symbol
    result += roman_map[s[-1]]
    
    return result

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    s = input("Enter the Roman numeral: ")
    
    # Get the result
    result = romanToInt(s)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the Roman numeral:  XI
# Output: 11

# %% [markdown]
# # Built-In Functions
# # 12. Length of Last Word
# Given a string s consisting of words and spaces, return the length of the last word in the string.
# A word is a maximal substring consisting of non-space characters only.

# %%
def lengthOfLastWord(s):
    # Strip any trailing spaces and split the string by spaces
    words = s.strip().split()
    
    # Return the length of the last word
    return len(words[-1])

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    s = input("Enter the string: ")
    
    # Get the result
    result = lengthOfLastWord(s)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the string:  Kritansh
# Output: 8

# %% [markdown]
# # 13. To Lower Case
# Given a string s, return the string after replacing every uppercase letter with the same lowercase letter.

# %%
def toLowerCase(s):
    # Use the built-in lower() function to convert all uppercase letters to lowercase
    return s.lower()

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    s = input("Enter the string: ")
    
    # Get the result
    result = toLowerCase(s)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the string:  KRISHA
# Output: krisha

# %% [markdown]
# # Simulation
# # 14. Baseball Game
# You are keeping the scores for a baseball game with strange rules. At the beginning of the game, you start with an empty record.
#
# You are given a list of strings operations, where operations[i] is the ith operation you must apply to the record and is one of the following:
#
# An integer x.
# Record a new score of x.
# '+'.
# Record a new score that is the sum of the previous two scores.
# 'D'.
# Record a new score that is the double of the previous score.
# 'C'.
# Invalidate the previous score, removing it from the record.
# Return the sum of all the scores on the record after applying all the operations.
#
# The test cases are generated such that the answer and all intermediate calculations fit in a 32-bit integer and that all operations are valid.

# %%
def calPoints(operations):
    # Initialize an empty list to store the scores
    record = []
    
    for operation in operations:
        if operation == 'C':
            # Remove the last score if 'C' is encountered
            record.pop()
        elif operation == 'D':
            # Double the last score if 'D' is encountered
            record.append(record[-1] * 2)
        elif operation == '+':
            # Add the sum of the last two scores if '+' is encountered
            record.append(record[-1] + record[-2])
        else:
            # Convert the operation to an integer and add it to the record
            record.append(int(operation))
    
    # Return the sum of all the scores in the record
    return sum(record)

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    operations = input("Enter the operations (separated by space): ").split()
    
    # Get the result
    result = calPoints(operations)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the operations (separated by space):  5 3 2
# Output: 10

# %% [markdown]
# # 15. Robot Return to Origin
# There is a robot starting at the position (0, 0), the origin, on a 2D plane. Given a sequence of its moves, judge if this robot ends up at (0, 0) after it completes its moves.
# You are given a string moves that represents the move sequence of the robot where moves[i] represents its ith move. Valid moves are 'R' (right), 'L' (left), 'U' (up), and 'D' (down).
# Return true if the robot returns to the origin after it finishes all of its moves, or false otherwise.
#
# Note: The way that the robot is "facing" is irrelevant. 'R' will always make the robot move to the right once, 'L' will always make it move left, etc. Also, assume that the magnitude of the robot's movement is the same for each move.

# %%
def judgeCircle(moves):
    # Initialize coordinates (x, y) of the robot
    x, y = 0, 0
    
    # Iterate through each move in the moves string
    for move in moves:
        if move == 'U':
            y += 1  # Move up increases the y-coordinate
        elif move == 'D':
            y -= 1  # Move down decreases the y-coordinate
        elif move == 'L':
            x -= 1  # Move left decreases the x-coordinate
        elif move == 'R':
            x += 1  # Move right increases the x-coordinate
    
    # After all moves, check if the robot has returned to the origin (0, 0)
    return x == 0 and y == 0

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    moves = input("Enter the moves: ")
    
    # Get the result
    result = judgeCircle(moves)
    
    # Output the result
    print("Output:", result)
# Out:
# Enter the moves:  LL
# Output: False

# %% [markdown]
# # 16. Find Winner on a Tic Tac Toe Game
# Tic-tac-toe is played by two players A and B on a 3 x 3 grid. The rules of Tic-Tac-Toe are:
#
# Players take turns placing characters into empty squares ' '.
# The first player A always places 'X' characters, while the second player B always places 'O' characters.
# 'X' and 'O' characters are always placed into empty squares, never on filled ones.
# The game ends when there are three of the same (non-empty) character filling any row, column, or diagonal.
# The game also ends if all squares are non-empty.
# No more moves can be played if the game is over.
# Given a 2D integer array moves where moves[i] = [rowi, coli] indicates that the ith move will be played on grid[rowi][coli]. return the winner of the game if it exists (A or B). In case the game ends in a draw return "Draw". If there are still movements to play return "Pending".
#
# You can assume that moves is valid (i.e., it follows the rules of Tic-Tac-Toe), the grid is initially empty, and A will play first.

# %%
def tictactoe(moves):
    # Initialize the 3x3 board
    board = [[' ' for _ in range(3)] for _ in range(3)]

    # Function to check if there is a winner
    def check_winner():
        # Check rows and columns
        for i in range(3):
            if board[i][0] == board[i][1] == board[i][2] != ' ':
                return board[i][0]
            if board[0][i] == board[1][i] == board[2][i] != ' ':
                return board[0][i]
        
        # Check diagonals
        if board[0][0] == board[1][1] == board[2][2] != ' ':
            return board[0][0]
        if board[0][2] == board[1][1] == board[2][0] != ' ':
            return board[0][2]
        
        return None

    # Simulate the game
    for i, move in enumerate(moves):
        row, col = move
        player = 'X' if i % 2 == 0 else 'O'  # Player A (X) and Player B (O)
        board[row][col] = player
        
        # Check for a winner after each move
        winner = check_winner()
        if winner:
            return "A" if winner == 'X' else "B"

    # If all moves are done but no winner, check if there are empty spots
    if len(moves) == 9:
        return "Draw"
    
    return "Pending"

# Example usage with input
if __name__ == "__main__":
    # Input from the user
    moves = [[int(x) for x in input("Enter move (row col): ").split()] for _ in range(int(input("How many moves? ")))]
    
    # Get the result
    result = tictactoe(moves)
    
    # Output the result
    print("Output:", result)
# Out:
# How many moves?  0
# Output: Pending

# %% [markdown]
# # 17. Robot Bounded In Circle
# On an infinite plane, a robot initially stands at (0, 0) and faces north. Note that:
#
# The north direction is the positive direction of the y-axis.
# The south direction is the negative direction of the y-axis.
# The east direction is the positive direction of the x-axis.
# The west direction is the negative direction of the x-axis.
# The robot can receive one of three instructions:
#
# "G": go straight 1 unit.
# "L": turn 90 degrees to the left (i.e., anti-clockwise direction).
# "R": turn 90 degrees to the right (i.e., clockwise direction).
# The robot performs the instructions given in order, and repeats them forever.
#
# Return true if and only if there exists a circle in the plane such that the robot never leaves the circle.

# %%
def isRobotBounded(instructions: str) -> bool:
    # Directions: North, East, South, West
    # (dx, dy) for each direction
    directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]
    
    # Initial position (0, 0) and initial direction (facing north)
    x, y = 0, 0
    direction = 0  # 0 -> North, 1 -> East, 2 -> South, 3 -> West
    
    for instruction in instructions:
        if instruction == 'G':
            # Move in the current direction
            dx, dy = directions[direction]
            x += dx
            y += dy
        elif instruction == 'L':
            # Turn left (counterclockwise), so decrease direction index
            direction = (direction - 1) % 4
        elif instruction == 'R':
            # Turn right (clockwise), so increase direction index
            direction = (direction + 1) % 4
    
    # If the robot is back at the origin or not facing north, it's bounded
    return (x == 0 and y == 0) or direction != 0

# Example usage:
instructions = "GGLLGG"
print(isRobotBounded(instructions))  # Output: True

instructions = "GG"
print(isRobotBounded(instructions))  # Output: False

instructions = "GL"
print(isRobotBounded(instructions))  # Output: True
# Out:
# True
# False
# True

# %% [markdown]
# # Matrix
# # 18. Count Odd Numbers in an Interval Range
# Given two non-negative integers low and high. Return the count of odd numbers between low and high (inclusive).

# %%
def count_odds(low, high):
    # Calculate the count of odd numbers in the range
    return (high + 1) // 2 - (low // 2)

# Input
low = int(input("Enter the lower bound (low): "))
high = int(input("Enter the upper bound (high): "))

# Output
print("Count of odd numbers between", low, "and", high, "is:", count_odds(low, high))
# Out:
# Enter the lower bound (low):  4
# Enter the upper bound (high):  6
# Count of odd numbers between 4 and 6 is: 1

# %% [markdown]
# # 19. Average Salary Excluding the Minimum and Maximum Salary
# You are given an array of unique integers salary where salary[i] is the salary of the ith employee.
# Return the average salary of employees excluding the minimum and maximum salary. Answers within 10-5 of the actual answer will be accepted.

# %%
def average_salary(salary):
    # Remove the minimum and maximum salary
    min_salary = min(salary)
    max_salary = max(salary)
    salary_sum = sum(salary) - min_salary - max_salary
    # Calculate the average excluding the minimum and maximum
    return salary_sum / (len(salary) - 2)

# Input
salary = list(map(int, input("Enter the salaries separated by spaces: ").split()))

# Output
print("Average salary excluding the minimum and maximum:", f"{average_salary(salary):.5f}")
# Out:
# Enter the salaries separated by spaces:  4500
# Average salary excluding the minimum and maximum: 4500.00000

# %% [markdown]
# # 20. Lemonade Change
# At a lemonade stand, each lemonade costs $5$. Customers are standing in a queue to buy from you and order one at a time (in the order specified by bills). Each customer will only buy one lemonade and pay with either a $5, $10, or $20$ bill. You must provide the correct change to each customer so that the net transaction is that the customer pays $5.
#
# Note that you do not have any change in hand at first.
#
# Given an integer array bills where bills[i] is the bill the ith customer pays, return true if you can provide every customer with the correct change, or false otherwise.

# %%
def lemonade_change(bills):
    # Initialize counters for $5 and $10 bills
    five, ten = 0, 0

    for bill in bills:
        if bill == 5:
            # Collect $5 bill
            five += 1
        elif bill == 10:
            # Collect $10 bill and give back one $5 as change
            if five > 0:
                five -= 1
                ten += 1
            else:
                return False
        elif bill == 20:
            # Collect $20 bill, prioritize giving one $10 and one $5 as change
            if ten > 0 and five > 0:
                ten -= 1
                five -= 1
            elif five >= 3:
                # Otherwise, give three $5 bills as change
                five -= 3
            else:
                return False

    return True

# Input
bills = list(map(int, input("Enter the bills separated by spaces: ").split()))

# Output
print("Can provide correct change to all customers:", lemonade_change(bills))
# Out:
# Enter the bills separated by spaces:  456 8765 432
# Can provide correct change to all customers: True

# %% [markdown]
# # 21. Largest Perimeter Triangle
# Given an integer array nums, return the largest perimeter of a triangle with a non-zero area, formed from three of these lengths. If it is impossible to form any triangle of a non-zero area, return 0.

# %%
def largest_perimeter(nums):
    # Sort the array in descending order
    nums.sort(reverse=True)

    # Iterate over the array to find the largest valid triangle
    for i in range(len(nums) - 2):
        # Check if the triangle inequality is satisfied
        if nums[i] < nums[i + 1] + nums[i + 2]:
            # Return the perimeter of the triangle
            return nums[i] + nums[i + 1] + nums[i + 2]

    # If no valid triangle is found, return 0
    return 0

# Input
nums = list(map(int, input("Enter the side lengths separated by spaces: ").split()))

# Output
print("Largest perimeter of a triangle:", largest_perimeter(nums))
# Out:
# Enter the side lengths separated by spaces:  23 54 65
# Largest perimeter of a triangle: 142

# %% [markdown]
# # 22. Check If It Is a Straight Line
# You are given an array coordinates, coordinates[i] = [x, y], where [x, y] represents the coordinate of a point. Check if these points make a straight line in the XY plane.

# %%
def check_straight_line(coordinates):
    # Calculate the slope between the first two points
    x0, y0 = coordinates[0]
    x1, y1 = coordinates[1]
    
    # The slope is represented by (y1 - y0) / (x1 - x0) 
    # but we avoid division by calculating the cross product
    dx = x1 - x0
    dy = y1 - y0

    # Check all other points against this slope
    for i in range(2, len(coordinates)):
        x, y = coordinates[i]
        # Use the cross product to check if (x - x0) * dy == (y - y0) * dx
        if (x - x0) * dy != (y - y0) * dx:
            return False

    return True

# Input
coordinates = [
    list(map(int, input("Enter the x and y coordinates separated by space: ").split()))
    for _ in range(int(input("Enter the number of points: ")))
]

# Output
print("Do the points form a straight line?", check_straight_line(coordinates))
# Out:
# Enter the number of points:  4
# Enter the x and y coordinates separated by space:  3 4
# Enter the x and y coordinates separated by space:  34 56
# Enter the x and y coordinates separated by space:  32 43
# Enter the x and y coordinates separated by space:  32 43
# Do the points form a straight line? False

# %% [markdown]
# # 23. Add Binary
# Given two binary strings a and b, return their sum as a binary string.

# %%
def add_binary(a, b):
    # Convert binary strings to integers, add them, and convert back to binary string
    return bin(int(a, 2) + int(b, 2))[2:]

# Example usage
a = input("Enter binary string a: ")
b = input("Enter binary string b: ")
result = add_binary(a, b)
print("Sum as binary string:", result)
# Out:
# Enter binary string a:  10
# Enter binary string b:  101011
# Sum as binary string: 101101

# %% [markdown]
# # 24. Multiply Strings
# Given two non-negative integers num1 and num2 represented as strings, return the product of num1 and num2, also represented as a string.
#
# Note: You must not use any built-in BigInteger library or convert the inputs to integer directly.

# %%
def multiply(num1, num2):
    # Edge case: if any number is "0", the result is "0"
    if num1 == "0" or num2 == "0":
        return "0"

    # Initialize a result array with zeros to store intermediate results
    result = [0] * (len(num1) + len(num2))

    # Reverse both strings to process from least significant digit to most significant
    num1 = num1[::-1]
    num2 = num2[::-1]

    # Multiply each digit from num1 by each digit from num2
    for i in range(len(num1)):
        for j in range(len(num2)):
            # Multiply current digits and add to the corresponding position in the result array
            product = int(num1[i]) * int(num2[j])
            result[i + j] += product
            # Handle carry over to the next position
            result[i + j + 1] += result[i + j] // 10
            result[i + j] %= 10

    # Remove leading zeros in the result array (if any)
    while len(result) > 1 and result[-1] == 0:
        result.pop()

    # Reverse the result array and convert it back to a string
    return ''.join(map(str, result[::-1]))

# Example usage
num1 = input("Enter num1: ")
num2 = input("Enter num2: ")
print("Product:", multiply(num1, num2))
# Out:
# Enter num1:  45
# Enter num2:  54
# Product: 2430

# %% [markdown]
# # 25. Pow(x, n)
# Implement pow(x, n), which calculates x raised to the power n (i.e., xn).

# %%
def myPow(x, n):
    # Helper function for recursive power calculation
    def helper(x, n):
        if n == 0:
            return 1  # base case: x^0 = 1
        half = helper(x, n // 2)  # compute x^(n//2)
        if n % 2 == 0:
            return half * half  # if n is even, return (x^(n//2))^2
        else:
            return half * half * x  # if n is odd, return (x^(n//2))^2 * x
    
    # Handle negative exponents
    if n < 0:
        x = 1 / x
        n = -n
    
    return helper(x, n)

# Example usage
x = float(input("Enter x: "))
n = int(input("Enter n: "))
print("Result:", myPow(x, n))
# Out:
# Enter x:  4
# Enter n:  15
# Result: 1073741824.0
